# %% [markdown]
# <a href="https://colab.research.google.com/github/kottongs/Mypythoncodes/blob/firstbranch/myfirstgraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
x = (2,4,5,6,8)
y = (4,7,9,12,15)
plt.plot(x,y)
plt.title('linear graph')
plt.xlabel('x - axis ')
plt.ylabel('y - axis')
plt.show()
